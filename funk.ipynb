# %% [markdown]
# ## imports

# %%
import os
import time
from datetime import datetime

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from dotenv import load_dotenv

# %% [markdown]
# # --- PARÁMETROS ESPECÍFICOS PARA LA TAREA ---

# %%
# Rango de años
YEARS = [2010, 2024]

# %%
# Lista de géneros relacionados con funk
funk_related_genres = [
    # Funk clásico
    "funk",
    "classic funk",
    "deep funk",
    "funky",
    "funky breaks",
    "p-funk",
    "funk rock",
    "funk metal",
    "afro funk",
    "jazz funk",
    "disco funk",
    "boogie",
    "old school funk",

    # Soul / neo soul
    "soul",
    "classic soul",
    "neo soul",
    "contemporary r&b",
    "motown",
    "funk soul",

    # Funk house / dance
    "funk house",
    "disco house",
    "funky house",
    "deep funk house",
    "electro funk",
    "dance funk",
    "groove house"
]

# Términos para búsqueda
query_terms = funk_related_genres

# %% [markdown]
# ## CARGAMOS CREDENCIALES DESDE .env

# %%
load_dotenv()  # Carga variables del archivo .env

SPOTIPY_CLIENT_ID = os.getenv("SPOTIPY_CLIENT_ID")
SPOTIPY_CLIENT_SECRET = os.getenv("SPOTIPY_CLIENT_SECRET")
LASTFM_API_KEY = os.getenv("LASTFM_API_KEY")
LASTFM_USER_AGENT = os.getenv("LASTFM_USER_AGENT", "spotify-lastfm-project")

if not SPOTIPY_CLIENT_ID or not SPOTIPY_CLIENT_SECRET:
    raise ValueError("Faltan SPOTIPY_CLIENT_ID o SPOTIPY_CLIENT_SECRET en el archivo .env")
if not LASTFM_API_KEY:
    raise ValueError("Falta LASTFM_API_KEY en el archivo .env")

# %% [markdown]
# ## INICIALIZAMOS CLIENTE SPOTIFY

# %%
try:
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
        client_id=SPOTIPY_CLIENT_ID,
        client_secret=SPOTIPY_CLIENT_SECRET
    ))
    print("✅ Conexión a Spotify exitosa.")
except Exception as e:
    print(f"❌ Error de conexión a Spotify: {e}")
    sp = None

print("Objeto sp:", type(sp))
# Out:
# ✅ Conexión a Spotify exitosa.
# Objeto sp: <class 'spotipy.client.Spotify'>

# %% [markdown]
# ## EXTRAEMOS CANCIONES TRACKS (FUNk Y SUBGENEROS)

# %% [markdown]
# ## EXTRAEMOS DETALLES DE ALBUM

# %%
import pandas as pd
import time

def extract_spotify_data_funk(
    sp,
    years,
    query_terms,
    max_total_songs=500,
    max_songs_per_year=250
):
    spotify_data = []
    total_songs = 0

    for year in years:
        songs_in_year = 0
        print(f"\n--- EXTRAYENDO AÑO {year} ---")

        for term in query_terms:
            if total_songs >= max_total_songs:
                print("⚠️ Límite global alcanzado")
                return pd.DataFrame(spotify_data)

            query = f'{term} year:{year}'
            print(f"🔎 {query}")

            results = sp.search(q=query, type="track", limit=50)

            while results and songs_in_year < max_songs_per_year and total_songs < max_total_songs:

                for track in results["tracks"]["items"]:
                    track_id = track["id"]

                    # evitar duplicados
                    if any(d["ID_Spotify"] == track_id for d in spotify_data):
                        continue

                    spotify_data.append({
                        "Artista": track["artists"][0]["name"],
                        "Genero": "funk",
                        "Origen_busqueda": term,
                        "Cancion": track["name"],
                        "Year": year,
                        "ID_Spotify": track_id,
                        "ID_Album": track["album"]["id"],
                        "Popularidad": track["popularity"]
                    })

                    songs_in_year += 1
                    total_songs += 1

                    if songs_in_year >= max_songs_per_year or total_songs >= max_total_songs:
                        break

                # paginación
                if results["tracks"]["next"]:
                    results = sp.next(results["tracks"])
                    time.sleep(1)
                else:
                    break

        print(f"✅ Año {year}: {songs_in_year} canciones")

    return pd.DataFrame(spotify_data)

# %%
# DIAGNÓSTICO: Verificar parámetros de entrada
print("\n=== DIAGNÓSTICO ===")
print(f"Conexión sp: {sp is not None}")
print(f"YEARS: {YEARS}")
print(f"query_terms: {query_terms}")
print(f"Tipo de query_terms: {type(query_terms)}")

# Prueba manual de búsqueda simple
try:
    test_search = sp.search(q='funk', type='track', limit=5)
    print(f"\n✅ Búsqueda manual exitosa: {len(test_search['tracks']['items'])} resultados")
    if test_search['tracks']['items']:
        print(f"Ejemplo: {test_search['tracks']['items'][0]['name']}")
except Exception as e:
    print(f"❌ Error en búsqueda manual: {e}")
# Out:
# === DIAGNÓSTICO ===
# Conexión sp: True
# YEARS: [2010, 2024]
# query_terms: ['funk', 'classic funk', 'deep funk', 'funky', 'funky breaks', 'p-funk', 'funk rock', 'funk metal', 'afro funk', 'jazz funk', 'disco funk', 'boogie', 'old school funk', 'soul', 'classic soul', 'neo soul', 'contemporary r&b', 'motown', 'funk soul', 'funk house', 'disco house', 'funky house', 'deep funk house', 'electro funk', 'dance funk', 'groove house']
# Tipo de query_terms: <class 'list'>
#
# ✅ Búsqueda manual exitosa: 5 resultados
# Ejemplo: Funk de Beleza - Slowed

# %% [markdown]
# ## ALBUMES + TRACKS

# %%
df_spotify_raw = extract_spotify_data_funk(
    sp,
    YEARS,
    query_terms,
    max_total_songs=500,
    max_songs_per_year=250
)

print(f"Número de canciones encontradas en df_spotify_raw: {len(df_spotify_raw)}")
print(df_spotify_raw.head())
# Out:
# --- EXTRAYENDO AÑO 2010 ---
# 🔎 funk year:2010
# 🔎 classic funk year:2010
# 🔎 deep funk year:2010
# 🔎 funky year:2010
# 🔎 funky breaks year:2010
# 🔎 p-funk year:2010
# 🔎 funk rock year:2010
# 🔎 funk metal year:2010
# 🔎 afro funk year:2010
# 🔎 jazz funk year:2010
# 🔎 disco funk year:2010
# 🔎 boogie year:2010
# 🔎 old school funk year:2010
# 🔎 soul year:2010
# 🔎 classic soul year:2010
# 🔎 neo soul year:2010
# 🔎 contemporary r&b year:2010
# 🔎 motown year:2010
# 🔎 funk soul year:2010
# 🔎 funk house year:2010
# 🔎 disco house year:2010
# 🔎 funky house year:2010
# 🔎 deep funk house year:2010
# 🔎 electro funk year:2010
# 🔎 dance funk year:2010
# 🔎 groove house year:2010
# ✅ Año 2010: 250 canciones
#
# --- EXTRAYENDO AÑO 2024 ---
# 🔎 funk year:2024
# 🔎 classic funk year:2024
# 🔎 deep funk year:2024
# 🔎 funky year:2024
# ⚠️ Límite global alcanzado
# Número de canciones encontradas en df_spotify_raw: 500
#           Artista Genero Origen_busqueda              Cancion  Year  \
# 0     Bryce Janey   funk            funk   Funky Guitar Blues  2010
# 1     Funky Bijou   funk            funk   Funky Bijou Anthem  2010
# 2           Kasír   funk            funk     The Funky Spider  2010
# 3  La Discothèque   funk            funk            Funkytown  2010
# 4      Tom Browne   funk            funk  Funkin' for Jamaica  2010
#
#                ID_Spotify                ID_Album  Popularidad
# 0  2dqkDzJPwSIduZlKJh0lvB  1ULW18kqQ47Qp3YUATkvFQ           42
# 1  3vqJENUjIAwBiWs5zVLWha  4ieRodIyGcBr9uU20D2MQU           35
# 2  5LXgUQ5VRmm7PsVBTnQyOn  6tZRWMS69RdXXvcuSC0ILj           34
# 3  3fehLpIWjlE3YnTXRkqPN1  6CXNfnJUwEHFYUaiUNmeby           34
# 4  1es1B258zAVeXx6uzksrJd  34psLr9vLAgw49ehAgo6SJ           28

# %%
# VERIFICACIÓN DE CANCIONES
print(f"Número de canciones encontradas en df_spotify_raw: {len(df_spotify_raw)}")
print(f"Primeras filas (head) de df_spotify_raw:\n{df_spotify_raw.head()}")
# Out:
# Número de canciones encontradas en df_spotify_raw: 500
# Primeras filas (head) de df_spotify_raw:
#           Artista Genero Origen_busqueda              Cancion  Year  \
# 0     Bryce Janey   funk            funk   Funky Guitar Blues  2010
# 1     Funky Bijou   funk            funk   Funky Bijou Anthem  2010
# 2           Kasír   funk            funk     The Funky Spider  2010
# 3  La Discothèque   funk            funk            Funkytown  2010
# 4      Tom Browne   funk            funk  Funkin' for Jamaica  2010
#
#                ID_Spotify                ID_Album  Popularidad
# 0  2dqkDzJPwSIduZlKJh0lvB  1ULW18kqQ47Qp3YUATkvFQ           42
# 1  3vqJENUjIAwBiWs5zVLWha  4ieRodIyGcBr9uU20D2MQU           35
# 2  5LXgUQ5VRmm7PsVBTnQyOn  6tZRWMS69RdXXvcuSC0ILj           34
# 3  3fehLpIWjlE3YnTXRkqPN1  6CXNfnJUwEHFYUaiUNmeby           34
# 4  1es1B258zAVeXx6uzksrJd  34psLr9vLAgw49ehAgo6SJ           28

# %% [markdown]
# ## HACEMOS EXTRACCION DESDE LAST.FM

# %%
import requests

def get_lastfm_artist_info(artist_name):
    """
    Usa artist.getInfo para obtener:
    - Biografía breve
    - Listeners y playcount
    - Lista de artistas similares
    """
    base_url = "https://ws.audioscrobbler.com/2.0/"
    params = {
        "method": "artist.getInfo",
        "api_key": LASTFM_API_KEY,
        "artist": artist_name,
        "format": "json",
        "autocorrect": 1
    }
    headers = {"user-agent": LASTFM_USER_AGENT}

    try:
        resp = requests.get(base_url, params=params, headers=headers, timeout=10)
        data = resp.json()

        if "artist" not in data:
            return None

        a = data["artist"]

        # Popularidad / estadísticas
        stats = a.get("stats", {})
        listeners = stats.get("listeners")
        playcount = stats.get("playcount")

        # Biografía: cogemos la versión corta (summary) y la recortamos un poco
        bio = a.get("bio", {}).get("summary", "")
        bio_short = bio.split("<a href=")[0].strip() if bio else ""

        # Artistas similares (nombres)
        similars = a.get("similar", {}).get("artist", [])
        similar_names = [s.get("name") for s in similars][:5]

        return {
            "Artista": artist_name,
            "Biografia_Resumen": bio_short,
            "Listeners_LastFM": listeners,
            "Playcount_LastFM": playcount,
            "Artistas_Similares": ", ".join(similar_names)
        }

    except Exception as e:
        print(f"Error Last.fm (artist.getInfo) para {artist_name}: {e}")
        return None

# %%
def build_lastfm_artist_df(df_spotify_raw, sleep_time=0.2):
    unique_artists = df_spotify_raw["Artista"].dropna().unique()
    lastfm_rows = []

    print(f"\n--- EXTRACCIÓN LAST.FM PARA {len(unique_artists)} ARTISTAS ---")

    for idx, artist in enumerate(unique_artists, start=1):
        info = get_lastfm_artist_info(artist)
        if info is None:
            info = {
                "Artista": artist,
                "Biografia_Resumen": None,
                "Listeners_LastFM": None,
                "Playcount_LastFM": None,
                "Artistas_Similares": None
            }

        lastfm_rows.append(info)
        # comenta esta línea para que no saque cada artista:
        # print(f"Procesado artista Last.fm {idx}/{len(unique_artists)}: {artist}")
        time.sleep(sleep_time)

    df_lastfm = pd.DataFrame(lastfm_rows)
    return df_lastfm

# %%
df_lastfm = build_lastfm_artist_df(df_spotify_raw, sleep_time=0.2)

print("\n--- EJEMPLO DE ARTISTAS LAST.FM (10 FILAS) ---")
print(df_lastfm.head(10))

df_proyecto_final = pd.merge(
    df_spotify_raw,
    df_lastfm,
    on="Artista",
    how="left"
)

output_filename = "musicstream_funk_lastfm_2010_2024.csv"
df_proyecto_final.to_csv(output_filename, index=False, encoding="utf-8")

print("\n🎉 ¡FASE 1 COMPLETA CON SPOTIFY + LAST.FM! 🎉")
print(f"Archivo guardado como: {output_filename}")
print(f"Filas totales en df_proyecto_final: {len(df_proyecto_final)}")
print("\n--- EJEMPLO DE 10 FILAS DEL DF FINAL ---")
print(df_proyecto_final.head(10))
# Out:
# --- EXTRACCIÓN LAST.FM PARA 312 ARTISTAS ---
#
# --- EJEMPLO DE ARTISTAS LAST.FM (10 FILAS) ---
#             Artista                                  Biografia_Resumen  \
# 0       Bryce Janey  Bryce Janey began his career at age thirteen i...
# 1       Funky Bijou
# 2             Kasír  Kasír are a young Danish trio, who play Irish ...
# 3    La Discothèque
# 4        Tom Browne  Tom Browne (born October 30, 1954, Queens, New...
# 5    The Funky Town
# 6       Mr. Talkbox
# 7      The Sequence  "The Sequence" can refer to either a 1980's hi...
# 8          Maxipaul
# 9  The Jive Turkeys
#
#   Listeners_LastFM Playcount_LastFM  \
# 0            25748           142353
# 1             8626            56316
# 2            11027            66571
# 3             4609            14002
# 4           173816           828300
# 5             1521             5346
# 6             5806            31243
# 7            23294           138613
# 8              307             1209
# 9             8026            36293
#
#                                   Artistas_Similares
# 0  Tony Spinner, Philip Sayce Group, Jason Elmore...
# 1  Atomic Project, A.Skillz, Dj Lean Rock, Illag,...
# 2  The Outside Track, Pádraig Rynne, John McSherr...
# 3  The Disco Orchestra, The Disco Brothers, Toni ...
# 4  Bobbi Humphrey, Loose Ends, Con Funk Shun, Ron...
# 5  Sensation Ltd, The Matons, Jwl, Overwings, The...
# 6  Chesterfield People, We Are Leo, Dogg Master, ...
# 7  The Sugarhill Gang, Kurtis Blow, Grandmaster F...
# 8  Head Horny's, dj miguel serna, Alfredo pareja,...
# 9  Jimmy Jules & The Nuclear Soul System, On the ...
#
# 🎉 ¡FASE 1 COMPLETA CON SPOTIFY + LAST.FM! 🎉
# Archivo guardado como: musicstream_funk_lastfm_2010_2024.csv
# Filas totales en df_proyecto_final: 500
#
# --- EJEMPLO DE 10 FILAS DEL DF FINAL ---
#             Artista Genero Origen_busqueda                     Cancion  Year  \
# 0       Bryce Janey   funk            funk          Funky Guitar Blues  2010
# 1       Funky Bijou   funk            funk          Funky Bijou Anthem  2010
# 2             Kasír   funk            funk            The Funky Spider  2010
# 3    La Discothèque   funk            funk                   Funkytown  2010
# 4        Tom Browne   funk            funk         Funkin' for Jamaica  2010
# 5    The Funky Town   funk            funk       Funky Town - 80's Mix  2010
# 6       Mr. Talkbox   funk            funk            Funkadelic Sound  2010
# 7      The Sequence   funk            funk  Funk You Up (12'' Version)  2010
# 8          Maxipaul   funk            funk          Funk (Klubbed Mix)  2010
# 9  The Jive Turkeys   funk            funk              Funky Brewster  2010
#
#                ID_Spotify                ID_Album  Popularidad  \
# 0  2dqkDzJPwSIduZlKJh0lvB  1ULW18kqQ47Qp3YUATkvFQ           42
# 1  3vqJENUjIAwBiWs5zVLWha  4ieRodIyGcBr9uU20D2MQU           35
# 2  5LXgUQ5VRmm7PsVBTnQyOn  6tZRWMS69RdXXvcuSC0ILj           34
# 3  3fehLpIWjlE3YnTXRkqPN1  6CXNfnJUwEHFYUaiUNmeby           34
# 4  1es1B258zAVeXx6uzksrJd  34psLr9vLAgw49ehAgo6SJ           28
# 5  19fsi2eY2FehBaIWb6IQYT  7MlkH4VAR03h19qaTVMFjn           23
# 6  4Nh2oQHhRcVy16qYbRQ2Fw  0m5koUYDRGH9y53Kv9v9kV           26
# 7  0IPMwsreFCYEYvzsvolNMf  5zxoU8Y4gWUyNcRLjknWky           23
# 8  5unrlCzR2G5A2O3Mpiw6mS  1e6kxyfq7sQkg4naSIPEXm            7
# 9  2OQierF1V3Cr1VRPuJ7p8U  1G8Wn22GUexwkJWWqbnusb           21
#
#                                    Biografia_Resumen Listeners_LastFM  \
# 0  Bryce Janey began his career at age thirteen i...            25748
# 1                                                                8626
# 2  Kasír are a young Danish trio, who play Irish ...            11027
# 3                                                                4609
# 4  Tom Browne (born October 30, 1954, Queens, New...           173816
# 5                                                                1521
# 6                                                                5806
# 7  "The Sequence" can refer to either a 1980's hi...            23294
# 8                                                                 307
# 9                                                                8026
#
#   Playcount_LastFM                                 Artistas_Similares
# 0           142353  Tony Spinner, Philip Sayce Group, Jason Elmore...
# 1            56316  Atomic Project, A.Skillz, Dj Lean Rock, Illag,...
# 2            66571  The Outside Track, Pádraig Rynne, John McSherr...
# 3            14002  The Disco Orchestra, The Disco Brothers, Toni ...
# 4           828300  Bobbi Humphrey, Loose Ends, Con Funk Shun, Ron...
# 5             5346  Sensation Ltd, The Matons, Jwl, Overwings, The...
# 6            31243  Chesterfield People, We Are Leo, Dogg Master, ...
# 7           138613  The Sugarhill Gang, Kurtis Blow, Grandmaster F...
# 8             1209  Head Horny's, dj miguel serna, Alfredo pareja,...
# 9            36293  Jimmy Jules & The Nuclear Soul System, On the ...

# %% [markdown]
# ## fase 2: BBDD SQL

# %%
import pandas as pd

# 1️⃣ Cargar CSV
df = pd.read_csv("musicstream_funk_lastfm_2010_2024.csv")

# 2️⃣ Eliminar columnas de audio features (aunque no existan)
df = df.drop(
    columns=['Bailabilidad', 'Energia', 'Valence', 'Tempo'],
    errors='ignore'
)

# 3️⃣ (Opcional pero muy recomendado) Normalizar nombres de columnas
df = df.rename(columns={
    'Artista': 'artista',
    'Género musical': 'genero',
    'Tipo': 'tipo',
    'Nombre': 'cancion',
    'Año de lanzamiento': 'year',
    'ID_Spotify': 'spotify_id',
    'ID_Album': 'album_id',
    'Popularidad': 'spotify_popularity',
    'Biografia_Resumen': 'bio_lastfm',
    'Listeners_LastFM': 'lastfm_listeners',
    'Playcount_LastFM': 'lastfm_playcount',
    'Artistas_Similares': 'similar_artists'
})

# 4️⃣ Verificación final
print(df.columns.tolist())
df.head()
# Out:
# ['artista', 'genero', 'tipo', 'cancion', 'year', 'spotify_id', 'album_id', 'spotify_popularity', 'bio_lastfm', 'lastfm_listeners', 'lastfm_playcount', 'similar_artists']
#           artista               genero     tipo              cancion  year  \
# 0     Bryce Janey  funk (Origen: funk)  Canción   Funky Guitar Blues  2010
# 1     Funky Bijou  funk (Origen: funk)  Canción   Funky Bijou Anthem  2010
# 2           Kasír  funk (Origen: funk)  Canción     The Funky Spider  2010
# 3  La Discothèque  funk (Origen: funk)  Canción            Funkytown  2010
# 4      Tom Browne  funk (Origen: funk)  Canción  Funkin' for Jamaica  2010
#
#                spotify_id                album_id  spotify_popularity  \
# 0  2dqkDzJPwSIduZlKJh0lvB  1ULW18kqQ47Qp3YUATkvFQ                  42
# 1  3vqJENUjIAwBiWs5zVLWha  4ieRodIyGcBr9uU20D2MQU                  35
# 2  5LXgUQ5VRmm7PsVBTnQyOn  6tZRWMS69RdXXvcuSC0ILj                  34
# 3  3fehLpIWjlE3YnTXRkqPN1  6CXNfnJUwEHFYUaiUNmeby                  34
# 4  1es1B258zAVeXx6uzksrJd  34psLr9vLAgw49ehAgo6SJ                  28
#
#                                           bio_lastfm  lastfm_listeners  \
# 0  Bryce Janey began his career at age thirteen i...           25748.0
# 1                                                NaN            8626.0
# 2  Kasír are a young Danish trio, who play Irish ...           11027.0
# 3                                                NaN            4609.0
# 4  Tom Browne (born October 30, 1954, Queens, New...          173816.0
#
#    lastfm_playcount                                    similar_artists
# 0          142353.0  Tony Spinner, Philip Sayce Group, Jason Elmore...
# 1           56316.0  Atomic Project, A.Skillz, Dj Lean Rock, Illag,...
# 2           66571.0  The Outside Track, Pádraig Rynne, John McSherr...
# 3           14002.0  The Disco Orchestra, The Disco Brothers, Toni ...
# 4          828300.0  Bobbi Humphrey, Loose Ends, Con Funk Shun, Ron...

# %%
# !pip install mysql-connector-python
# O usa el que suele ser más robusto con Pandas:
# !pip install sqlalchemy mysqlclient
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\pc\appdata\local\programs\python\python313\lib\site-packages (9.5.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sqlalchemy in c:\users\pc\appdata\local\programs\python\python313\lib\site-packages (2.0.45)
# Requirement already satisfied: mysqlclient in c:\users\pc\appdata\local\programs\python\python313\lib\site-packages (2.2.7)
# Requirement already satisfied: greenlet>=1 in c:\users\pc\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\pc\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.15.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
import pandas as pd

# =====================================
# 1. Parámetros de conexión y nombres
# =====================================
MYSQL_HOST = "localhost"
MYSQL_USER = "root"
MYSQL_PASSWORD = "AlumnaAdalab"

DB_NAME = "funk_db"                  # nombre de tu BBDD
TABLE_NAME = "tracks_funk"           # nombre de tabla
CSV_FILE = "musicstream_funk_lastfm_2010_2024.csv"   # tu CSV final


# =====================================
# 2. Crear BBDD si no existe
# =====================================
conn_root = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    password=MYSQL_PASSWORD
)
cursor_root = conn_root.cursor()

cursor_root.execute(f"CREATE DATABASE IF NOT EXISTS {DB_NAME}")
print(f"✅ Base de datos '{DB_NAME}' creada o verificada en el servidor.")

cursor_root.close()
conn_root.close()


# =====================================
# 3. Conectarse a la BBDD funk_db
# =====================================
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    password=MYSQL_PASSWORD,
    database=DB_NAME
)
cursor = conn.cursor()
print(f"✅ Conexión establecida a la base de datos MySQL: {DB_NAME}")


# =====================================
# 4. Cargar CSV con pandas
# =====================================
df = pd.read_csv(CSV_FILE)
filas = len(df)

# (OPCIONAL) Renombrar alguna columna si lo necesitas, por ejemplo:
# df = df.rename(columns={"Artista": "artista", "Nombre": "titulo_cancion"})

print(f"✅ Datos cargados y columna renombrada: {filas} filas.")


# =====================================
# 5. Crear tabla (ejemplo sencillo)
#    Ajusta tipos según tus columnas reales
# =====================================

# Borro la tabla si ya existe (opcional durante desarrollo)
cursor.execute(f"DROP TABLE IF EXISTS {TABLE_NAME}")

create_table_sql = f"""
CREATE TABLE {TABLE_NAME} (
    id INT AUTO_INCREMENT PRIMARY KEY,
    Artista VARCHAR(255),
    `Género musical` VARCHAR(255),
    Tipo VARCHAR(50),
    Nombre VARCHAR(255),
    `Año de lanzamiento` INT,
    ID_Spotify VARCHAR(50),
    ID_Album VARCHAR(50),
    Biografia_Resumen TEXT,
    Listeners_LastFM BIGINT,
    Playcount_LastFM BIGINT
);
"""
cursor.execute(create_table_sql)
conn.commit()


# =====================================
# 6. Insertar datos de pandas en MySQL
# =====================================

insert_sql = f"""
INSERT INTO {TABLE_NAME} (
    Artista, `Género musical`, Tipo, Nombre, `Año de lanzamiento`,
    ID_Spotify, ID_Album, Biografia_Resumen, Listeners_LastFM, Playcount_LastFM
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

for _, row in df.iterrows():
    cursor.execute(insert_sql, (
        row.get("Artista"),
        row.get("Género musical"),
        row.get("Tipo"),
        row.get("Nombre"),
        int(row.get("Año de lanzamiento")) if pd.notna(row.get("Año de lanzamiento")) else None,
        row.get("ID_Spotify"),
        row.get("ID_Album"),
        row.get("Biografia_Resumen"),
        int(row.get("Listeners_LastFM")) if pd.notna(row.get("Listeners_LastFM")) else None,
        int(row.get("Playcount_LastFM")) if pd.notna(row.get("Playcount_LastFM")) else None
    ))

conn.commit()
print(f"✅ Insertadas {filas} filas en la tabla {TABLE_NAME}.")

cursor.close()
conn.close()
print("✅ Conexión cerrada.")
# Out:
# ✅ Base de datos 'funk_db' creada o verificada en el servidor.
# ✅ Conexión establecida a la base de datos MySQL: funk_db
# ✅ Datos cargados y columna renombrada: 500 filas.
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'nan' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[23], line 97
#      89 insert_sql = f"""
#      90 INSERT INTO {TABLE_NAME} (
#      91     Artista, `Género musical`, Tipo, Nombre, `Año de lanzamiento`,
#      92     ID_Spotify, ID_Album, Biografia_Resumen, Listeners_LastFM, Playcount_LastFM
#      93 ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#      94 """
#      96 for _, row in df.iterrows():
# ---> 97     cursor.execute(insert_sql, (
#      98         row.get("Artista"),
#      99         row.get("Género musical"),
#     100         row.get("Tipo"),
#     101         row.get("Nombre"),
#     102         int(row.get("Año de lanzamiento")) if pd.notna(row.get("Año de lanzamiento")) else None,
#     103         row.get("ID_Spotify"),
#     104         row.get("ID_Album"),
#     105         row.get("Biografia_Resumen"),
#     106         int(row.get("Listeners_LastFM")) if pd.notna(row.get("Listeners_LastFM")) else None,
#     107         int(row.get("Playcount_LastFM")) if pd.notna(row.get("Playcount_LastFM")) else None
#     108     ))
#     110 conn.commit()
#     111 print(f"✅ Insertadas {filas} filas en la tabla {TABLE_NAME}.")
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# ProgrammingError: 1054 (42S22): Unknown column 'nan' in 'field list'
